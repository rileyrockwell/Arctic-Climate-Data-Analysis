# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/workspaces/Arctic-Climate-Data-Analysis/data/fairbanks_international.csv")

# %%
df_1 = df[['DATE', 'PRCP', 'SNWD', 'TMAX', 'TMIN']]

# %%
df_1
# Out:
#              DATE  PRCP   SNWD  TMAX  TMIN
# 0      1930-01-01   0.0  279.0 -28.3 -37.2
# 1      1930-01-02   0.3  279.0 -28.9 -37.2
# 2      1930-01-03   0.3  305.0 -20.6 -38.9
# 3      1930-01-04   0.0  305.0 -16.7 -27.8
# 4      1930-01-05   0.0  305.0 -21.1 -27.8
# ...           ...   ...    ...   ...   ...
# 35133  2026-03-11   0.0  838.0 -21.7 -40.6
# 35134  2026-03-12   0.0  838.0 -17.2 -40.0
# 35135  2026-03-13   0.0  838.0 -18.9 -37.8
# 35136  2026-03-14   0.0  813.0 -15.6 -32.8
# 35137  2026-03-15   0.0  813.0 -14.4 -35.6
#
# [35138 rows x 5 columns]

# %%
a = df_1['TMIN'].median(skipna=True)
b = df_1['TMAX'].median(skipna=True)
c = df_1['TMIN'].min()
d = df_1['TMAX'].max()

# %%
print(a, b, c, d)
# Out:
# -5.0 4.4 -54.4 35.6
